# %% [markdown]
# <a href="https://colab.research.google.com/github/MelissaSequeira/VITCS-IR-Day/blob/main/IISERVIOLATIONPROJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
w!pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 135.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HIOrnDyDEYCsm6i6tjfo")
project = rf.workspace("hello-znkqp").project("iiser_mohali_violation_detection-bjzxd")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to IISER_Mohali_Violation_Detection-4 in yolov8:: 100%|██████████| 5290/5290 [00:00<00:00, 5676.26it/s]

# %%
# !cat {dataset.location}/data.yaml
# Out:
# names:
# - helmet
# - motorcycle
# - rider
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: iiser_mohali_violation_detection-bjzxd
#   url: https://universe.roboflow.com/hello-znkqp/iiser_mohali_violation_detection-bjzxd/dataset/4
#   version: 4
#   workspace: hello-znkqp
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
print(dataset.location)
# Out:
# /content/IISER_Mohali_Violation_Detection-4

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # small & fast (recommended first)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(
    data="/content/IISER_Mohali_Violation_Detection-4/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,
    workers=8,
    patience=0,
    optimizer="AdamW",
    project="violation_runs",
    name="yolov8_100ep"
)
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Access precision, recall, f1-score and mAP from the metrics object
precision = metrics.box.mp  # Mean Precision
recall = metrics.box.mr     # Mean Recall
map50 = metrics.box.map50   # mAP at 50% IoU
map50_95 = metrics.box.map  # mAP at IoU range of 50-95%

# Convert to percentage and print
print(f"Precision: {precision*100:.2f}%")
print(f"Recall: {recall*100:.2f}%")
print(f"mAP50 (Accuracy @ 50% IoU): {map50*100:.2f}%")
print(f"mAP50-95 (Accuracy @ 50-95% IoU): {map50_95*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2302180844.py in <cell line: 0>()
#       1 # Access precision, recall, f1-score and mAP from the metrics object
# ----> 2 precision = metrics.box.mp  # Mean Precision
#       3 recall = metrics.box.mr     # Mean Recall
#       4 map50 = metrics.box.map50   # mAP at 50% IoU
#       5 map50_95 = metrics.box.map  # mAP at IoU range of 50-95%
#
# NameError: name 'metrics' is not defined
